# %% [markdown]
# # $WEST — Quick Start\n\nRun the full backtest in 3 clicks. No installation required.

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install -q yfinance pandas numpy matplotlib scipy statsmodels requests

# %% [markdown]
# ## 2. Download the engine

# %%
# !wget -q https://raw.githubusercontent.com/sehenriquez-ch/mississippi-west-index/main/mississippi_west.py

# %% [markdown]
# ## 3. Run the backtest (2016–2024)

# %%
from mississippi_west import main\nmain(start_date='2016-01-01', end_date='2024-12-31')
